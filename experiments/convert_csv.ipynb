# %%
import pandas as pd
import csv

# %%
pd.read_csv("Inv_3CPC_loc_DE.csv", delimiter=";", low_memory=False).to_csv("Inv_3CPC_loc_DE_conv.csv", sep=",", quoting=csv.QUOTE_ALL)

# %%
pd.read_csv("Inv_3CPC_loc_DE_conv.csv", delimiter=",")
# Out:
# /tmp/ipykernel_581305/2705305078.py:1: DtypeWarning: Columns (3,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("Inv_3CPC_loc_DE_conv.csv", delimiter=",")
#          Unnamed: 0   appln_id appln_auth      appln_nr appln_kind  \
# 0                 0        151         EP      07024389         A
# 1                 1        217         EP      08010186         A
# 2                 2        218         EP      08010192         A
# 3                 3        243         EP      08010251         A
# 4                 4        266         EP      08010352         A
# ...             ...        ...        ...           ...        ...
# 2239748     2239748  417932626         EP      14168297         A
# 2239749     2239749  417945890         US  201213676367         A
# 2239750     2239750  410143413         EP      13004314         A
# 2239751     2239751  330264513         DE  102010045579         A
# ...
